# %%
from itertools import product

class Board:
    """The game board.

    Contains information about:
        locations of chess pieces
        number of active pieces

    x-axis: a-h
    y-axis: 1-8
    """
    def __init__(self):
        self.board = {(x,y):None for x in range(8) for y in range(8)}
        self.pieceCount = 32
        self.whitePieces = 16
        self.blackPieces = 16
        self.SpawnAll()
        self.DisplayBoard()
        self.BKingcanCastleL = True
        self.WKingcanCastleL = True
        self.BKingcanCastleR = True
        self.WKingcanCastleR = True

    def SpawnAll(self):
        for x in range(8):
              self.board[(x, 1)] = pawn('pawn', 'white')
        self.board[(1, 0)] = knight('knight', 'white')
        self.board[(6,0)] = knight('knight', 'white')
        self.board[(0,0)] = rook('rook', 'white')
        self.board[(7,0)] = rook('rook', 'white')
        self.board[(2,0)] = bishop('bishop', 'white')
        self.board[(5,0)] = bishop('bishop', 'white')
        self.board[(4,0)] = king('king', 'white')
        self.board[(3,0)] = queen('king', 'white')
        #spawn black pieces
        for x in range(8):
              self.board[(x, 6)] = pawn('pawn', 'black')
        self.board[(1, 7)] = knight('knight', 'black')
        self.board[(6,7)] = knight('knight', 'black')
        self.board[(0,7)] = rook('rook', 'black')
        self.board[(7,7)] = rook('rook' , 'black')
        self.board[(2,7)] = bishop('bishop', 'black')
        self.board[(5,7)] = bishop('bishop', 'black')
        self.board[(4,7)] = king('king', 'black')
        self.board[(3,7)] = queen('queen', 'black')

    def DisplayBoard(self):
        print(self.board)

    def GetPieceCount(self):
        print(self.pieceCount)

    def promotion(self, dest, game):
        piece = self.board[dest]
        if piece.color == 'black' and dest[1] == 7:
            print('pawn promotion! choose a piece to promote to\
            (knight, bishop, rook, queen): ')
            piece.piecetype = input()
            return None
        if piece.color == 'white' and dest[1] == 0:
            print('pawn promotion! choose a piece to promote to\
            (knight, bishop, rook, queen): ')
            piece.piecetype = input()
            return None

    """
    Moves a piece from one location to another
    Parameters:
        piece: the chess piece to move
        loc: the current location of the chess piece
        dest: the destination to move to
        game: the game
    """
    def Move(self, loc, dest, game):
        piece = self.board[loc] # the piece object to move
        if piece == None:
            print("There's nobody there, ya dingus!")
            return None

        if piece.color != game.currentPlayer:
            print("he ain't your guy ya dingus!")
            return None

        if (dest[0] not in range(8) or dest[1] not in range(8)):
            print("That destination ain't on the board, ya dingus!")
            return None
        
        legalMoves = piece.legalmoves() # a list of all possible movement vectors
        attemptedMove = (dest[0]-loc[0],dest[1]-loc[1])
        
        if (piece.piecetype == 'king') and (self.WKingcanCastleL == True):
            if (attemptedMove == (2,0)) and \
            ((self.board[(5,0)] and self.board[(6,0)]) == None) and \
            (self.board[(7,0)] == 'rook'):
                self.board[dest] = piece
                self.board[loc] = None
                self.board[5,0] = 'rook'
                self.board[7,0] = None
        if (piece.piecetype == 'king') and (self.WKingcanCastleR == True):
            if (attemptedMove == (-2,0)) and \
            ((self.board[(1,0)] and self.board[(2,0)] and self.board[(3,0)]) == None) and \
            (self.board[(0,0)] == 'rook'):
                self.board[dest] = piece
                self.board[loc] = None
                self.board[3,0] = 'rook'
                self.board[0,0] = None
        if (piece.piecetype == 'king') and (self.BKingcanCastleL == True):
            if (attemptedMove == (2,0)) and \
            ((self.board[(5,7)] and self.board[(6,7)]) == None) and \
            (self.board[(7,7)] == 'rook'):
                self.board[dest] = piece
                self.board[loc] = None
                self.board[5,7] = 'rook'
                self.board[7,7] = None
        if (piece.piecetype == 'king') and (self.BKingcanCastleR == True):
            if (attemptedMove == (-2,0)) and \
            ((self.board[(1,7)] and self.board[(2,7)] and self.board[(3,7)]) == None) and \
            (self.board[(0,7)] == 'rook'):
                self.board[dest] = piece
                self.board[loc] = None
                self.board[3,7] = 'rook'
                self.board[0,7] = None

        if piece.piecetype == 'pawn':
            if (attemptedMove[0] != 0) and (self.board[dest] == None):
                print('pawns can only move diagonally if an enemy is there')
                return None
            if (attemptedMove == ((0,1) or (0,-1))) and (self.board[dest] != None):
                print('pawns cannot kill things directly in front of them')
                return None
            if (attemptedMove == ((0,2) or (0,-2))) and (loc[1] != (1 or 6)):
                print('pawns can move two spaces only their first move')
                return None
        
        if attemptedMove not in legalMoves: # If the destination is not possible to move to
            print("Not a legal move")
            return None
        #leftright
        if (attemptedMove[0] != 0 and attemptedMove[1]) == 0 and (piece.piecetype == ('rook' or 'queen')):
            left = min(loc[0],dest[0])
            right = max(loc[0],dest[0])
            checkblock = [(a,loc[1]) for a in range(left,right)]
            for i in range(len(checkblock)):
                if self.board[checkblock[i]] != None:
                    print('blocked1')
                    return None
                    #ada
        #updown
        print(piece.piecetype)
        if (attemptedMove[0] == 0 and attemptedMove[1] != 0) and (piece.piecetype == ('rook' or 'queen')):
            bot = min(loc[1],dest[1])
            top = max(loc[1],dest[1])
            checkblock = [(loc[0],a) for a in range(bot,top)]
            for i in range(len(checkblock)):
                if self.board[checkblock[i]] != None:
                    print('blocked2')
                    return None
        #diagonal
        if (attemptedMove[0] == attemptedMove[1]) and (piece.piecetype == ('bishop' or 'queen')):
            botleftx = min(loc[0],dest[0])
            botlefty = min(loc[1],dest[1])
            toprightx = max(loc[0],dest[0])
            toprighty = max(loc[1],dest[1])
            for j in range(abs(attemptedMove[0])):
                checkblock += [(botleftx+j,botlefty+j)]
            for i in range(len(checkblock)):
                if self.board[checkblock[i]] != None:
                    print('blocked3')
                    return None
        if (attemptedMove[0] == -(attemptedMove[1])) and (piece.piecetype == ('bishop' or 'queen')):
            topleftx = min(loc[0],dest[0])
            toplefty = max(loc[1],dest[1])
            botrightx = max(loc[0],dest[0])
            botrighty = min(loc[1],dest[1])
            for j in range(abs(attemptedMove[0])):
                checkblock += [(topleftx+j,toplefty-j)]
            for i in range(len(checkblock)):
                if self.board[checkblock[i]] != None:
                    print('blocked4')
                    return None

        if self.board[dest] != None:
            if self.board[dest].color == game.currentPlayer: # If you are moving to a space with your own unit
                print("You already have a guy there")
                return None
            else:
                print("You killed a guy!")
                print(piece)
                self.board[dest] = piece
                self.pieceCount -= 1
                if game.currentPlayer == "white":
                    self.blackPieces -= 1
                    print(self.blackPieces)
                    game.CurrentPlayer = "black"
                else:
                    self.whitePieces -= 1
                    print(self.whitePieces)
                    game.CurrentPlayer = "white"
                self.board[loc] = None
                print("It is now %s\'s turn" % (game.currentPlayer))

        else:
            print(piece)
            self.board[dest] = piece
            self.board[loc] = None
            if piece.piecetype == 'king':
                if piece.color == 'black':
                    self.BKingcanCastleL = False
                    self.BKingcanCastleR = False
                else:
                    self.WKingcanCastleL = False
                    self.WKingcanCastleR = False
            if piece.piecetype == 'rook':
                if loc == (7,0):
                    self.WKingcanCastleL = False
                if loc == (0,0):
                    self.WKingcanCastleR = False
                if loc == (7,7):
                    self.BKingcanCastleL = False
                if loc == (0,7):
                    self.BKingcanCastleR = False
            if piece.piecetype == 'pawn':
                self.promotion(dest,game)
            game.ChangePlayer()
            print("It is now %s\'s turn" % (game.currentPlayer))


class chesspiece(object):
    horizontal = [(a,0) for a in range(-7,8)]
    horizontal.remove((0,0))
    vertical = [(0,b) for b in range(-7,8)]
    vertical.remove((0,0))
    diagonal1 = [(a,a) for a in range(-7,8)]
    diagonal1.remove((0,0))
    diagonal2 = [(a,-a) for a in range(-7,8)]
    diagonal2.remove((0,0))
    def __init__(self,piecetype,color):
        self.piecetype = piecetype
        self.color = color

class king(chesspiece):
    # king.piecetype = 'king'
    def legalmoves():
        kingmoves = [(a,b) for a,b in product(range(-1,2),repeat = 2)]
        kingmoves.remove((0,0))
        castlemove = [(-2,0),(2,0)]
        return kingmoves+castlemove

class queen(chesspiece):
    # queen.piecetype = 'queen'
    def legalmoves(self):
        return horizontal+vertical+diagonal1+diagonal2

class bishop(chesspiece):
    # bishop.piecetype = 'bishop'
    def legalmoves(self):
        return diagonal1+diagonal2

class knight(chesspiece):
    # knight.piecetype = 'knight'
    def legalmoves(self):
        return [(-1,2), (1,2), (2,1), (2,-1), (-2,1), (-2,1), (1,-2), (-1,-2)]

class rook(chesspiece):
    # rook.piecetype = 'rook'
    def legalmoves(self):
        return self.horizontal+self.vertical

class pawn(chesspiece):
    # pawn.piecetype = 'pawn'
    def legalmoves(self):
        if self.color == "white":
            return [(0,1),(0,2),(-1,1),(1,1)]
        elif self.color == "black":
            return [(0,-1),(0,-2),(-1,-1),(1,-1)]


class rungame():
    def __init__(self):
        self.gameboardinstance = Board()
        self.currentPlayer = "white"

    def GetCurrentPlayer(self):
        return self.currentPlayer

    def ChangePlayer(self):
        if self.currentPlayer == "white":
            self.currentPlayer = "black"
        elif self.currentPlayer == "black":
            self.currentPlayer = "white"
        else:
            print("I don't know who's turn it is")

    def getinput(self):
        print('enter a location and destination as tuples:')
        playermove = input()

# %%
# Out:
# {(7, 3): None, (4, 7): <__main__.king object at 0xb45888cc>, (1, 3): None, (6, 4): None, (3, 0): <__main__.queen object at 0xb45889cc>, (5, 4): None, (0, 7): <__main__.rook object at 0xb4588bac>, (5, 6): <__main__.pawn object at 0xb4588b4c>, (0, 0): <__main__.rook object at 0xb45889ec>, (1, 6): <__main__.pawn object at 0xb4588f6c>, (5, 1): <__main__.pawn object at 0xb45888ac>, (3, 7): <__main__.queen object at 0xb4588b6c>, (0, 3): None, (2, 5): None, (7, 2): None, (4, 0): <__main__.king object at 0xb4588e2c>, (1, 2): None, (6, 7): <__main__.knight object at 0xb4588a2c>, (3, 3): None, (0, 6): <__main__.pawn object at 0xb458896c>, (7, 6): <__main__.pawn object at 0xb45888ec>, (4, 4): None, (6, 3): None, (1, 5): None, (3, 6): <__main__.pawn object at 0xb4588fcc>, (0, 4): None, (7, 7): <__main__.rook object at 0xb458872c>, (5, 7): <__main__.bishop object at 0xb4588aec>, (5, 3): None, (4, 1): <__main__.pawn object at 0xb45889ac>, (1, 1): <__main__.pawn object at 0xb4588f0c>, (0, 1): <__main__.pawn object at 0xb4588ccc>, (3, 2): None, (2, 6): <__main__.pawn object at 0xb4588dcc>, (6, 6): <__main__.pawn object at 0xb4588b8c>, (5, 0): <__main__.bishop object at 0xb45884cc>, (7, 1): <__main__.pawn object at 0xb4588ecc>, (4, 5): None, (2, 2): None, (5, 5): None, (1, 4): None, (6, 0): <__main__.knight object at 0xb4588b0c>, (7, 5): None, (0, 5): None, (2, 1): <__main__.pawn object at 0xb4588e0c>, (4, 2): None, (1, 0): <__main__.knight object at 0xb4588e6c>, (6, 5): None, (3, 5): None, (2, 7): <__main__.bishop object at 0xb4588a4c>, (7, 0): <__main__.rook object at 0xb4588a6c>, (4, 6): <__main__.pawn object at 0xb4588dec>, (3, 4): None, (6, 1): <__main__.pawn object at 0xb458884c>, (3, 1): <__main__.pawn object at 0xb4588a8c>, (2, 4): None, (7, 4): None, (2, 0): <__main__.bishop object at 0xb4588a0c>, (6, 2): None, (4, 3): None, (1, 7): <__main__.knight object at 0xb4588f8c>, (2, 3): None, (5, 2): None, (0, 2): None}

# %%
game=rungame()
game.gameboardinstance.Move((0,1),(0,3), game)
# game.gameboardinstance.Move((0,6),(0,4), game)
game.gameboardinstance.Move((0,3),(1,4), game)
game.gameboardinstance.Move((0,6),(0,4), game)
game.gameboardinstance.Move((0,4),(0,3), game)
# Out:
# {(7, 3): None, (4, 7): <__main__.king object at 0xb45b084c>, (1, 3): None, (6, 4): None, (3, 0): <__main__.queen object at 0xb4588bac>, (5, 4): None, (0, 7): <__main__.rook object at 0xb45b0aac>, (5, 6): <__main__.pawn object at 0xb45b09cc>, (0, 0): <__main__.rook object at 0xb4588b6c>, (1, 6): <__main__.pawn object at 0xb45888cc>, (5, 1): <__main__.pawn object at 0xb45888ec>, (3, 7): <__main__.queen object at 0xb45b0e2c>, (0, 3): None, (2, 5): None, (7, 2): None, (4, 0): <__main__.king object at 0xb4588b4c>, (1, 2): None, (6, 7): <__main__.knight object at 0xb45b0acc>, (3, 3): None, (0, 6): <__main__.pawn object at 0xb45889cc>, (7, 6): <__main__.pawn object at 0xb45b01ec>, (4, 4): None, (6, 3): None, (1, 5): None, (3, 6): <__main__.pawn object at 0xb4f3b60c>, (0, 4): None, (7, 7): <__main__.rook object at 0xb45b0ecc>, (5, 7): <__main__.bishop object at 0xb45b078c>, (5, 3): None, (4, 1): <__main__.pawn object at 0xb4588fcc>, (1, 1): <__main__.pawn object at 0xb45889ac>, (0, 1): <__main__.pawn object at 0xb4588dcc>, (3, 2): None, (2, 6): <__main__.pawn object at 0xb4f23b4c>, (6, 6): <__main__.pawn object at 0xb45b0fac>, (5, 0): <__main__.bishop object at 0xb45889ec>, (7, 1): <__main__.pawn object at 0xb4588a2c>, (4, 5): None, (2, 2): None, (5, 5): None, (1, 4): None, (6, 0): <__main__.knight object at 0xb4588ccc>, (7, 5): None, (0, 5): None, (2, 1): <__main__.pawn object at 0xb4588aec>, (4, 2): None, (1, 0): <__main__.knight object at 0xb4588e2c>, (6, 5): None, (3, 5): None, (2, 7): <__main__.bishop object at 0xb45b0f4c>, (7, 0): <__main__.rook object at 0xb45888ac>, (4, 6): <__main__.pawn object at 0xb45b004c>, (3, 4): None, (6, 1): <__main__.pawn object at 0xb458896c>, (3, 1): <__main__.pawn object at 0xb458872c>, (2, 4): None, (7, 4): None, (2, 0): <__main__.bishop object at 0xb4588f6c>, (6, 2): None, (4, 3): None, (1, 7): <__main__.knight object at 0xb45b0a0c>, (2, 3): None, (5, 2): None, (0, 2): None}
# pawn
# <__main__.pawn object at 0xb4588dcc>
# It is now black's turn
# he ain't your guy ya dingus!
# pawn
# <__main__.pawn object at 0xb45889cc>
# It is now white's turn
# he ain't your guy ya dingus!
